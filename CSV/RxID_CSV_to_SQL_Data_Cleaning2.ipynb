# %% [markdown]
# #RxId : CSV Data Cleaning
#
# Data Source : https://pillbox.nlm.nih.gov/developers.html
# https://dev.socrata.com/foundry/datadiscovery.nlm.nih.gov/crzr-uvwg
#
#
# Issue :  Two CSV files were downloaded from the above site.
#
#     Pillbox.NO.ID.csv  has useful meds data but no image_id  field to link it to a filename in the image library.
#
#     Pillbox.NO.IMAGE ID.csv  lacks useful meds data but HAS image_id  field to link it to a filename in the image library.
#
# Solution:   Clean CSV files individually and merge into single CSV that will be used to load an AWS RDS database

# %% [markdown]
# ### Load CSVs into dataframes

# %%
import pandas as pd
pd.options.display.max_columns = None

# %%
url1="https://raw.githubusercontent.com/labs12-rxid/DS/master/CSV/Pillbox.NO.ID.csv"
df1=pd.read_csv(url1)

url2="https://raw.githubusercontent.com/labs12-rxid/DS/master/CSV/Pillbox.IMAGE%20ID.csv"
df2=pd.read_csv(url2)


print(df1.shape)
df2.shape
# Out:
# C:\Users\Gutierrez\Anaconda3\envs\py3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (62,63,64,65,66,69,70,71) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (62898, 72)
# (62898, 24)

# %%
df1.columns
# Out:
# Index(['ID', 'Enabled?', 'created at', 'updated at', 'spp', 'setid', 'splsize',
#        'pillbox_size', 'splshape', 'splshape_text', 'pillbox_shape_text',
#        'splscore', 'pillbox_score', 'splimprint', 'pillbox_imprint',
#        'splcolor', 'splcolor_text', 'pillbox_color_text', 'spl_strength',
#        'spl_ingredients', 'spl_inactive_ing', 'source', 'rxtty', 'rxstring',
#        'rxcui', 'product_code', 'part_num', 'part_medicine_name', 'ndc9',
#        'ndc_labeler_code', 'ndc_product_code', 'medicine_name',
#        'marketing_act_code', 'effective_time', 'file_name',
#        'equal_product_code', 'dosage_form', 'document_type',
#        'dea_schedule_code', 'dea_schedule_name', 'author_type', 'author',
#        'approval_code', 'image_source', 'splimage', 'has_image', 'epc_match',
#        'version_number', 'laberer_code', 'application_number', 'updated',
#        'stale', 'new', 'Unnamed: 53', 'Unnamed: 54', 'Unnamed: 55',
#        'Unnamed: 56', 'Unnamed: 57', 'Unnamed: 58', 'Unnamed: 59',
#        'Unnamed: 60', 'Unnamed: 61', 'Unnamed: 62', 'Unnamed: 63',
#        'Unnamed: 64', 'Unnamed: 65', 'Unnamed: 66', 'Unnamed: 67',
#        'Unnamed: 68', 'Unnamed: 69', 'Unnamed: 70', 'Unnamed: 71'],
#       dtype='object')

# %% [markdown]
# ###  Rename df2.id to df2.ID  to match df1

# %%
df2.rename(columns={'id':'ID'}, inplace=True)
df2.columns
# Out:
# Index(['ID', 'spl_id', 'SETID', 'spp', 'NDC9', 'PRODUCT_CODE',
#        'EQUAL_PRODUCT_CODE', 'author', 'SPLIMPRINT', 'SPLCOLOR', 'SPLSHAPE',
#        'SPLSIZE', 'SPLSCORE', 'DEA_SCHEDULE_CODE', 'INGREDIENTS',
#        'SPL_INACTIVE_ING', 'RXCUI', 'RXTTY', 'RXSTRING', 'image_id',
#        'IMAGE_SOURCE', 'HAS_IMAGE', 'FROM_SIS', 'NO_RXCUI'],
#       dtype='object')

# %% [markdown]
# ### Drop Useless/Duplicated Columns from df1 & df2

# %%
drop_col_1=['created at', 'updated at', 'ndc9', 'author',
            'rxstring', 'has_image',
       'Unnamed: 53', 'Unnamed: 54', 'Unnamed: 55',
       'Unnamed: 56', 'Unnamed: 57', 'Unnamed: 58', 'Unnamed: 59',
       'Unnamed: 60', 'Unnamed: 61', 'Unnamed: 62', 'Unnamed: 63',
       'Unnamed: 64', 'Unnamed: 65', 'Unnamed: 66', 'Unnamed: 67',
       'Unnamed: 68', 'Unnamed: 69', 'Unnamed: 70', 'Unnamed: 71']
df1.drop(columns=drop_col_1, inplace=True)
df1.columns
# Out:
# Index(['ID', 'Enabled?', 'spp', 'setid', 'splsize', 'pillbox_size', 'splshape',
#        'splshape_text', 'pillbox_shape_text', 'splscore', 'pillbox_score',
#        'splimprint', 'pillbox_imprint', 'splcolor', 'splcolor_text',
#        'pillbox_color_text', 'spl_strength', 'spl_ingredients',
#        'spl_inactive_ing', 'source', 'rxtty', 'rxcui', 'product_code',
#        'part_num', 'part_medicine_name', 'ndc_labeler_code',
#        'ndc_product_code', 'medicine_name', 'marketing_act_code',
#        'effective_time', 'file_name', 'equal_product_code', 'dosage_form',
#        'document_type', 'dea_schedule_code', 'dea_schedule_name',
#        'author_type', 'approval_code', 'image_source', 'splimage', 'epc_match',
#        'version_number', 'laberer_code', 'application_number', 'updated',
#        'stale', 'new'],
#       dtype='object')

# %%
drop_col_2=['SETID', 'spp', 'INGREDIENTS','SPL_INACTIVE_ING','SPLSIZE', 'SPLSCORE',
           'SPLIMPRINT', 'SPLCOLOR',	'SPLSHAPE', 'RXCUI',	'RXTTY', 'IMAGE_SOURCE']
df2.drop(columns=drop_col_2, inplace=True)
df2.columns
# Out:
# Index(['ID', 'spl_id', 'NDC9', 'PRODUCT_CODE', 'EQUAL_PRODUCT_CODE', 'author',
#        'DEA_SCHEDULE_CODE', 'RXSTRING', 'image_id', 'HAS_IMAGE', 'FROM_SIS',
#        'NO_RXCUI'],
#       dtype='object')

# %% [markdown]
# ### compare same  ID acrross Frames

# %%
df1.query('ID==3143')
# Out:
#          ID  Enabled?                                               spp  \
# 25440  3143      True  e4682a6e-9624-48b0-978f-95da00cfb78f-0093-7372-0
#
#                                       setid  splsize  pillbox_size splshape  \
# 25440  e4682a6e-9624-48b0-978f-95da00cfb78f     19.0           NaN   C48336
#
#       splshape_text pillbox_shape_text  splscore  pillbox_score splimprint  \
# 25440       CAPSULE                NaN       1.0            NaN  TEVA;7372
#
#       pillbox_imprint       splcolor splcolor_text pillbox_color_text  \
# 25440             NaN  C48328;C48325    PINK;WHITE                NaN
#
#                                             spl_strength  \
# 25440  AMLODIPINE BESYLATE 5 mg;BENAZEPRIL HYDROCHLOR...
#
#                                          spl_ingredients  \
# 25440  AMLODIPINE BESYLATE[AMLODIPINE];BENAZEPRIL HYD...
#
#                                         spl_inactive_ing  \
# 25440  FERROSOFERRIC OXIDE;ANHYDROUS DIBASIC CALCIUM ...
#
#                                             source  \
# 25440   CORN;CROSPOVIDONE (15 MPA.S AT 5%);GELATIN
#
#                                                    rxtty rxcui  \
# 25440   UNSPECIFIED;LACTOSE MONOHYDRATE;MAGNESIUM STE...   SCD
#
#                                             product_code part_num  \
# 25440  Amlodipine 5 MG / Benazepril hydrochloride 20 ...   898356
#
#       part_medicine_name ndc_labeler_code ndc_product_code medicine_name  \
# 25440          0093-7372              NaN           937372            93
#
#       marketing_act_code                           effective_time file_name  \
# 25440               7372  Amlodipine and Benazepril Hydrochloride    active
#
#       equal_product_code                               dosage_form  \
# 25440           20170823  a804a97e-d1e0-411b-b075-557ac09684c0.xml
#
#       document_type dea_schedule_code dea_schedule_name author_type  \
# 25440           NaN            C25158           34391-3         NaN
#
#       approval_code              image_source splimage epc_match  \
# 25440       LABELER  Teva Pharmaceuticals USA     Inc.       SPL
#
#       version_number laberer_code application_number updated stale  new
# 25440       93737201         TRUE                NaN      16   NaN  NaN

# %%
df2.query('ID==3143')
# Out:
#          ID  spl_id       NDC9 PRODUCT_CODE EQUAL_PRODUCT_CODE  \
# 62894  3143     NaN  000937372    0093-7372                NaN
#
#                                author DEA_SCHEDULE_CODE  \
# 62894  Teva Pharmaceuticals USA, Inc.               NaN
#
#                                                 RXSTRING     image_id  \
# 62894  Amlodipine 5 MG / Benazepril hydrochloride 20 ...  00093737201
#
#        HAS_IMAGE  FROM_SIS  NO_RXCUI
# 62894          1       NaN       NaN

# %% [markdown]
# ###  Combine dataframes

# %%
df_comb=pd.merge(df1,df2,how='left', on=['ID'])

# %%
df_comb.query('ID==3143')
# Out:
#          ID  Enabled?                                               spp  \
# 25440  3143      True  e4682a6e-9624-48b0-978f-95da00cfb78f-0093-7372-0
#
#                                       setid  splsize  pillbox_size splshape  \
# 25440  e4682a6e-9624-48b0-978f-95da00cfb78f     19.0           NaN   C48336
#
#       splshape_text pillbox_shape_text  splscore  pillbox_score splimprint  \
# 25440       CAPSULE                NaN       1.0            NaN  TEVA;7372
#
#       pillbox_imprint       splcolor splcolor_text pillbox_color_text  \
# 25440             NaN  C48328;C48325    PINK;WHITE                NaN
#
#                                             spl_strength  \
# 25440  AMLODIPINE BESYLATE 5 mg;BENAZEPRIL HYDROCHLOR...
#
#                                          spl_ingredients  \
# 25440  AMLODIPINE BESYLATE[AMLODIPINE];BENAZEPRIL HYD...
#
#                                         spl_inactive_ing  \
# 25440  FERROSOFERRIC OXIDE;ANHYDROUS DIBASIC CALCIUM ...
#
#                                             source  \
# 25440   CORN;CROSPOVIDONE (15 MPA.S AT 5%);GELATIN
#
#                                                    rxtty rxcui  \
# 25440   UNSPECIFIED;LACTOSE MONOHYDRATE;MAGNESIUM STE...   SCD
#
#                                             product_code part_num  \
# 25440  Amlodipine 5 MG / Benazepril hydrochloride 20 ...   898356
#
#       part_medicine_name ndc_labeler_code ndc_product_code medicine_name  \
# 25440          0093-7372              NaN           937372            93
#
#       marketing_act_code                           effective_time file_name  \
# 25440               7372  Amlodipine and Benazepril Hydrochloride    active
#
#       equal_product_code                               dosage_form  \
# 25440           20170823  a804a97e-d1e0-411b-b075-557ac09684c0.xml
#
#       document_type dea_schedule_code dea_schedule_name author_type  \
# 25440           NaN            C25158           34391-3         NaN
#
#       approval_code              image_source splimage epc_match  \
# 25440       LABELER  Teva Pharmaceuticals USA     Inc.       SPL
#
#       version_number laberer_code application_number updated stale  new  \
# 25440       93737201         TRUE                NaN      16   NaN  NaN
#
#        spl_id       NDC9 PRODUCT_CODE EQUAL_PRODUCT_CODE  \
# 25440     NaN  000937372    0093-7372                NaN
#
#                                author DEA_SCHEDULE_CODE  \
# 25440  Teva Pharmaceuticals USA, Inc.               NaN
#
#                                                 RXSTRING     image_id  \
# 25440  Amlodipine 5 MG / Benazepril hydrochloride 20 ...  00093737201
#
#        HAS_IMAGE  FROM_SIS  NO_RXCUI
# 25440          1       NaN       NaN

# %% [markdown]
# ### Write out combined CSV

# %%
# df_comb.to_csv('Pills.Final.csv', index=False ) #header=['id','status_group'])

# %% [markdown]
# # USING FINAL CSV FILE

# %%
df = pd.read_csv('Pills.Final.csv')
df.head()
# Out:
# C:\Users\Gutierrez\Anaconda3\envs\py3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (45) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#       ID  Enabled?                                                spp  \
# 0  20466      True   9e8e429c-1960-4acd-8bc5-5002d4c6a6ac-21695-995-2
# 1  42363      True  782c1bb9-75c4-4258-97b6-fd776ca970f5-55154-3432-0
# 2  48946      True   a39bb616-9e84-4142-8450-824f88528906-51285-120-2
# 3  43308      True   d08cc0ab-4cb5-4290-8d46-5d8b66e8472e-65084-453-0
# 4  18502      True   fa1ec93e-35b0-43c9-81ee-69f7e8abea87-65841-748-0
#
#                                   setid  splsize  pillbox_size splshape  \
# 0  9e8e429c-1960-4acd-8bc5-5002d4c6a6ac      3.0           NaN   C48348
# 1  782c1bb9-75c4-4258-97b6-fd776ca970f5     15.0           NaN   C48345
# 2  a39bb616-9e84-4142-8450-824f88528906      6.0           NaN   C48348
# 3  d08cc0ab-4cb5-4290-8d46-5d8b66e8472e     14.0           NaN   C48345
# 4  fa1ec93e-35b0-43c9-81ee-69f7e8abea87     19.0           NaN   C48336
#
#   splshape_text pillbox_shape_text  splscore  pillbox_score    splimprint  \
# 0         ROUND                NaN       1.0            NaN        dp;519
# 1          OVAL                NaN       1.0            NaN          GGD6
# 2         ROUND                NaN       1.0            NaN        dp;331
# 3          OVAL                NaN       2.0            NaN     NORCO;539
# 4       CAPSULE                NaN       1.0            NaN  ZA;60;160;mg
#
#   pillbox_imprint       splcolor splcolor_text pillbox_color_text  \
# 0             NaN         C48329         GREEN                NaN
# 1             NaN         C48325         WHITE                NaN
# 2             NaN         C48329         GREEN                NaN
# 3             NaN         C48325         WHITE                NaN
# 4             NaN  C48333;C48333     BLUE;BLUE                NaN
#
#                                         spl_strength  \
# 0                                                NaN
# 1                   AZITHROMYCIN MONOHYDRATE 250 mg;
# 2                                                NaN
# 3  HYDROCODONE BITARTRATE 10 mg;ACETAMINOPHEN 325...
# 4                  PROPRANOLOL HYDROCHLORIDE 160 mg;
#
#                                      spl_ingredients  \
# 0
# 1  AZITHROMYCIN MONOHYDRATE[AZITHROMYCIN ANHYDROUS];
# 2
# 3  HYDROCODONE BITARTRATE[HYDROCODONE];ACETAMINOP...
# 4            PROPRANOLOL HYDROCHLORIDE[PROPRANOLOL];
#
#                                     spl_inactive_ing  \
# 0  D&C YELLOW NO. 10;FD&C BLUE NO. 1;FD&C YELLOW ...
# 1                           SILICON DIOXIDE;LECITHIN
# 2  D&C YELLOW NO. 10;FD&C BLUE NO. 1;FD&C YELLOW ...
# 3  CROSCARMELLOSE SODIUM;CROSPOVIDONE (15 MPA.S A...
# 4  ETHYLCELLULOSES;FD&C BLUE NO. 1;FERROSOFERRIC ...
#
#                                               source                rxtty  \
# 0                            MICROCRYSTALLINE;STARCH                CORN;
# 1   SOYBEAN;MAGNESIUM STEARATE;MICROCRYSTALLINE C...   UNSPECIFIED;STARCH
# 2                                              CORN;                  HRX
# 3                                 UNSPECIFIED;STARCH   CORN;STEARIC ACID;
# 4                                  MICROCRYSTALLINE;                  HRX
#
#                                                rxcui  \
# 0                                               BPCK
# 1                                                HRX
# 2  {21 (Desogestrel 0.15 MG / Ethinyl Estradiol 0...
# 3                                                SCD
# 4  24 HR Propranolol Hydrochloride 160 MG Extende...
#
#                                         product_code  \
# 0  {21 (Ethinyl Estradiol 0.02 MG / Levonorgestre...
# 1                                                SCD
# 2                                             762002
# 3  Acetaminophen 325 MG / Hydrocodone Bitartrate ...
# 4                                             856481
#
#                           part_num part_medicine_name ndc_labeler_code  \
# 0                           750268          21695-995            Inert
# 1  Azithromycin 250 MG Oral Tablet             308460                0
# 2                        51285-120                  2        512850120
# 3                           856999          65084-453              NaN
# 4                        65841-748                  0        658410748
#
#   ndc_product_code medicine_name         marketing_act_code  \
# 0        216950995         21695                        995
# 1              NaN     551543432                      55154
# 2            51285           120                   Mircette
# 3        650840453         65084                        453
# 4            65841           748  PROPRANOLOL HYDROCHLORIDE
#
#                             effective_time     file_name  \
# 0                                   Aviane        active
# 1                                     3432  Azithromycin
# 2                                   active      20170519
# 3  Hydrocodone Bitatrate and Acetaminophen        active
# 4                                   active      20140430
#
#                          equal_product_code  \
# 0                                  20111004
# 1                                    active
# 2  c4c9e9dc-7e2a-459a-93e5-e3347fb9b1ed.xml
# 3                                  20170614
# 4  e55102eb-608c-481d-af93-1caf96b37013.xml
#
#                                 dosage_form  \
# 0  9e8e429c-1960-4acd-8bc5-5002d4c6a6ac.xml
# 1                                  20180110
# 2                                       NaN
# 3  1aee5ab4-6f3d-44f4-952b-0a2aa7915679.xml
# 4                                       NaN
#
#                               document_type dea_schedule_code  \
# 0                                 0555-9045            C42998
# 1  b0acdcad-0d6d-4edc-a31f-7b1e3ab65ffc.xml         0781-1496
# 2                                    C42998               NaN
# 3                                 52544-161            C42998
# 4                                    C42916               NaN
#
#   dea_schedule_name author_type              approval_code  \
# 0           34391-3         NaN                    LABELER
# 1            C42931     34391-3                        NaN
# 2               NaN         NaN        Teva Women's Health
# 3           34391-3         NaN                    LABELER
# 4               NaN         NaN  Cadila Healthcare Limited
#
#               image_source         splimage epc_match version_number  \
# 0  Rebel Distributors Corp           C73584       NaN          FALSE
# 1                  LABELER  Cardinal Health       NaN            NaN
# 2                     Inc.           C73584       NaN          FALSE
# 3       Mckesson Rxpak Inc           C73584       NaN          FALSE
# 4                   C73584              NaN     FALSE            NaN
#
#   laberer_code application_number  spl_id       NDC9 PRODUCT_CODE  \
# 0            1                  1     NaN  216950995    21695-995
# 1        FALSE                  1     NaN  551543432   55154-3432
# 2          NaN                  3     NaN  512850120    51285-120
# 3            1                  3     NaN  650840453    65084-453
# 4            1                NaN     NaN  658410748    65841-748
#
#   EQUAL_PRODUCT_CODE                     author DEA_SCHEDULE_CODE  \
# 0          0555-9045    Rebel Distributors Corp               NaN
# 1          0781-1496            Cardinal Health               NaN
# 2                NaN  Teva Women's Health, Inc.               NaN
# 3          52544-161         Mckesson Rxpak Inc               NaN
# 4                NaN  Cadila Healthcare Limited               NaN
#
#                                             RXSTRING image_id  HAS_IMAGE  \
# 0  {21 (Ethinyl Estradiol 0.02 MG / Levonorgestre...      NaN          0
# 1                    Azithromycin 250 MG Oral Tablet      NaN          0
# 2  {21 (Desogestrel 0.15 MG / Ethinyl Estradiol 0...      NaN          0
# 3  Acetaminophen 325 MG / Hydrocodone Bitartrate ...      NaN          0
# 4  24 HR Propranolol Hydrochloride 160 MG Extende...      NaN          0
#
#    FROM_SIS  NO_RXCUI
# 0       1.0       NaN
# 1       1.0       NaN
# 2       NaN       NaN
# 3       1.0       NaN
# 4       NaN       NaN

# %%
# DATAFRAME with 'image_id' of ROUND observations
df_round = df['image_id'][df['splshape'] == 'C48348'][df['HAS_IMAGE'] == 1]
df_round.shape
# Out:
# (4132,)

# %%
# DATAFRAME with 'image_id' of OVAL observations
df_oval = df['image_id'][df['splshape'] == 'C48345'][df['HAS_IMAGE'] == 1]
df_oval.shape
# Out:
# (2320,)

# %%
# DATAFRAME with 'image_id' of CAPSULE observations
df_capsule = df['image_id'][df['splshape'] == 'C48336'][df['HAS_IMAGE'] == 1]
df_capsule.shape
# Out:
# (1958,)

# %%
# Quick test on CAPSULE files
df_captest = df[['image_id', 'splshape', 'splshape_text']][df['splshape'] == 'C48336'][df['HAS_IMAGE'] == 1]
# Out:
# C:\Users\Gutierrez\Anaconda3\envs\py3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
df_captest.shape
# Out:
# (1958, 3)

# %%
df_captest['splshape_text'].value_counts()
# Out:
# CAPSULE    1958
# Name: splshape_text, dtype: int64

# %%
# Quick test on OVAL files
df_ovaltest = df[['image_id', 'splshape', 'splshape_text']][df['splshape'] == 'C48345'][df['HAS_IMAGE'] == 1]
# Out:
# C:\Users\Gutierrez\Anaconda3\envs\py3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
df_ovaltest.shape
# Out:
# (2320, 3)

# %%
df_ovaltest['splshape_text'].value_counts()
# Out:
# OVAL    2320
# Name: splshape_text, dtype: int64

# %%
len(df_capsule)
# Out:
# 1958

# %% [markdown]
# ### Copying ROUND image files to 'round_images' folder

# %%
# import os
# import shutil
# src = 'C:\\Users\\Gutierrez\\Documents\\DataScience\\lambda_school\\labs12-rxid\\DS\\pillbox_images'
# dest = 'C:\\Users\\Gutierrez\\Documents\\DataScience\\lambda_school\\labs12-rxid\\DS\\round_images'
# src_files = os.listdir(src)
# for file_name in df_round:
#     full_file_name = os.path.join(src, file_name + '.jpg')
#     if (os.path.isfile(full_file_name)):
#         shutil.copy(full_file_name, dest)

# %%
pwd
# Out:
# 'C:\\Users\\Gutierrez\\Documents\\DataScience\\lambda_school\\labs12-rxid\\DS\\CSV'

# %% [markdown]
# ### Copying OVAL image files to 'oval_images' folder

# %%
# import os
# import shutil
# src = 'C:\\Users\\Gutierrez\\Documents\\DataScience\\lambda_school\\labs12-rxid\\DS\\pillbox_images'
# dest = 'C:\\Users\\Gutierrez\\Documents\\DataScience\\lambda_school\\labs12-rxid\\DS\\oval_images'
# src_files = os.listdir(src)
# for file_name in df_oval:
#     full_file_name = os.path.join(src, file_name + '.jpg')
#     if (os.path.isfile(full_file_name)):
#         shutil.copy(full_file_name, dest)

# %% [markdown]
# ### Copying CAPSULE image files to 'capsule_images' folder

# %%
# import os
# import shutil
# src = 'C:\\Users\\Gutierrez\\Documents\\DataScience\\lambda_school\\labs12-rxid\\DS\\pillbox_images'
# dest = 'C:\\Users\\Gutierrez\\Documents\\DataScience\\lambda_school\\labs12-rxid\\DS\\capsule_images'
# src_files = os.listdir(src)
# for file_name in df_capsule:
#     full_file_name = os.path.join(src, file_name + '.jpg')
#     if (os.path.isfile(full_file_name)):
#         shutil.copy(full_file_name, dest)

# %% [markdown]
# # GETTING IMAGES INTO `TRAIN` & `TEST` FOLDER

# %% [markdown]
# ### Moving CAPSULE images to Training & Test folders

# %%
# import os
# import shutil
# src = 'C:\\Users\\Gutierrez\\Documents\\DataScience\\lambda_school\\labs12-rxid\\DS\\capsule_images'
# dest = 'C:\\Users\\Gutierrez\\Documents\\DataScience\\lambda_school\\labs12-rxid\\DS\\data\\train\\capsule'
# src_files = os.listdir(src)
# ctr = 1

# for file_name in df_capsule:
#     if ctr <= 1025:
#         full_file_name = os.path.join(src, file_name + '.jpg')
#         if (os.path.isfile(full_file_name)):
#             shutil.move(full_file_name, dest)
#             ctr += 1

# %%
df_oval.head()
# Out:
# 32                             675440060
# 92                00093-4740-01_F02D781B
# 132    00093-7569-56_NLMIMAGE10_2F4397AC
# 182                            003780734
# 207                            584680124
# Name: image_id, dtype: object

# %% [markdown]
# ### Moving CAPSULE images to Test folder

# %%
def img_traintest(shape, df):
    """
    Function to get images into Train and Test folders. 
    1025 for Train and 416 for Test.
    
    shape: Takes in a string for the shape.
    df: Takes in Pandas DataFrame/Series with images file names only.
    
    """

    import os
    import shutil
    src = 'C:\\Users\\Gutierrez\\Documents\\DataScience\\lambda_school\\labs12-rxid\\DS\\' + shape + '_images'
    dest1 = 'C:\\Users\\Gutierrez\\Documents\\DataScience\\lambda_school\\labs12-rxid\\DS\\data\\train\\' + shape
    dest2 = 'C:\\Users\\Gutierrez\\Documents\\DataScience\\lambda_school\\labs12-rxid\\DS\\data\\test\\' + shape
    src_files = os.listdir(src)
    ctr1 = 1
    ctr2 = 1
#     print(src)
#     print(dest1)
#     print(dest2)
#     print(f'df = {df.shape}')
    
    for file_name in df:
#         print(f'file_name:\n{file_name}')
        if ctr1 <= 1025:
            full_file_name = os.path.join(src, file_name + '.jpg')
            # print(f'full_file_name:\n{full_file_name}')
            if (os.path.isfile(full_file_name)):
                shutil.move(full_file_name, dest1)
                ctr1 += 1
                
        if ctr2 <= 416:
            full_file_name = os.path.join(src, file_name + '.jpg')
            if (os.path.isfile(full_file_name)):
                shutil.move(full_file_name, dest2)
                ctr2 += 1

# %%
# img_traintest("capsule", df_capsule)

# %%
# img_traintest("round", df_round)

# %%
# img_traintest('oval', df_oval)

# %% [markdown]
# # Splitting images in half vertically

# %% [markdown]
# #### ROUND "Train" Folder

# %%
def image_splitter(shape, train_or_test):
    '''
    Function to split images in train or test folder according based on shape.
    Function takes two strings, one for shape (i.e., round, capsule, oval) and another for either "train" or "test".
    '''
    
    import os
    import imageio
    
    # partial path for creating new directory and saving files
    partial_path = "C:\\Users\\Gutierrez\\Documents\\DataScience\\lambda_school\\labs12-rxid\\DS\\data\\"
    
    # making new folder for image halves
    new_folder = partial_path + train_or_test + "\\" + shape + "_h\\"

    os.makedirs(new_folder)
    
    # path to loop through
    folder_path = partial_path + train_or_test + "\\" + shape
    # print(folder_path)
    
    # image counter for image halves maded and saved
    img_ctr = 0
    
    # looping through all images in folder and processing
    for file in os.listdir(folder_path):
        file_name = os.path.join(folder_path, file)
        # print(file_name)
        img = imageio.imread(file_name)
        height, width = img.shape[:2]

        # Cut the image in half
        width_cutoff = width // 2
        s1 = img[:, :width_cutoff]
        s2 = img[:, width_cutoff:]
        
        # Save each half
        filepath_h1 = new_folder + "h1_" + file
        filepath_h2 = new_folder + "h2_" + file
        
        imageio.imwrite(filepath_h1, s1)
        imageio.imwrite(filepath_h2, s2)
        img_ctr +=2
        
    print('Total images (halves) saved:', img_ctr)

# %%
# image_splitter('round', 'train')
# Out:
# C:\Users\Gutierrez\Documents\DataScience\lambda_school\labs12-rxid\DS\data\train\round
# C:\Users\Gutierrez\Documents\DataScience\lambda_school\labs12-rxid\DS\data\train\round\
jpg
# C:\Users\Gutierrez\Documents\DataScience\lambda_school\labs12-rxid\DS\data\train\round\675440412.jpg
# C:\Users\Gutierrez\Documents\DataScience\lambda_school\labs12-rxid\DS\data\train\round\675440431.jpg
# C:\Users\Gutierrez\Documents\DataScience\lambda_school\labs12-rxid\DS\data\train\round\675440512.jpg
# C:\Users\Gutierrez\Documents\DataScience\lambda_school\labs12-rxid\DS\data\train\round\675440568.jpg
# C:\Users\Gutierrez\Documents\DataScience\lambda_school\labs12-rxid\DS\data\train\round\675440655.jpg
# C:\Users\Gutierrez\Documents\DataScience\lambda_school\labs12-rxid\DS\data\train\round\675440882.jpg
# C:\Users\Gutierrez\Documents\DataScience\lambda_school\labs12-rxid\DS\data\train\round\675440886.jpg
# C:\Users\Gutierrez\Documents\DataScience\lambda_school\labs12-rxid\DS\data\train\round\675440887.jpg
# C:\Users\Gutierrez\Documents\DataScience\lambda_school\labs12-rxid\DS\data\train\round\675440890.jpg
# C:\Users\Gutierrez\Documents\DataScience\lambda_school\labs12-rxid\DS\data\train\round\675440891.jpg
# C:\Users\Gutierrez\Documents\DataScience\lambda_school\labs12-rxid\DS\data\train\round\675440899.jpg
# C:\Users\Gutierrez\Documents\DataScience\lambda_school\labs12-rxid\DS\data\train\round\675460111.jpg
# C:\Users\Gutierrez\Documents\DataScience\lambda_school\labs12-rxid\DS\data\train\round\67767-0133-60_26269354.jpg
# C:\Users\Gutierrez\Documents\DataScience\lambda_school\labs12-rxid\DS\data\train\round\67877-0294-05_NLMIMAGE10_9140C8C6.jpg
# C:\Users\Gutierrez\Documents\DataScience\lambda_school\labs12-rxid\DS\data\train\round\680120309.jpg
# C:\Users\Gutierrez\Documents\DataScience\lambda_school\labs12-rxid\DS\data\train\round\680840248.jpg
# C:\Users\Gutierrez\Documents\DataScience\lambda_school\labs12-rxid\DS\data\train\round\680840457.jpg
# C:\Users\Gutierrez\Documents\DataScience\lambda_school\labs12-rxid\DS\data\train\round\68180-0519-02_19088CB4.jpg
# C:\Users\Gutierrez\Documents\DataScience\lambda_school\labs12-rxid\DS\data\train\round\681800515.jpg
# C:\Users\Gutierrez\Documents\DataScience\lambda_school\labs12-rxid\DS\data\train\round\68196-0159-14_NLMIMAGE10_8E38C726.jpg
# C:\Users\Gutierrez\Documents\DataScience\lambda_school\labs12-rxid\DS\data\train\round\68382-0001-16_DE086F73.jpg
# C:\Users\Gutierrez\Documents\DataScience\lambda_school\labs12-rxid\DS\data\train\round\68382-0040-01_7C0E3E01.jpg
# C:\Users\Gutierrez\Documents\DataScience\lambda_school\labs12-rxid\DS\data\train\round\68382-0097-06_D2086973.jpg
# C:\Users\Gutierrez\Documents\DataScience\lambda_school\labs12-rxid\DS\data\train\round\68382-0099-06_D6086B23.jpg
# C:\Users\Gutierrez\Documents\DataScience\lambda_school\labs12-rxid\DS\data\train\round\683820050.jpg
# C:\Users\Gutierrez\Documents\DataScience\lambda_school\labs12-rxid\DS\data\train\round\683820095.jpg
# C:\Users\Gutierrez\Documents\DataScience\lambda_school\labs12-rxid\DS\data\train\round\68462-0160-01_B123D88E.jpg
# C:\Users\Gutierrez\Documents\DataScience\lambda_school\labs12-rxid\DS\data\train\round\68462-0224-01_9216C956.jpg
# C:\Users\Gutierrez\Documents\DataScience\lambda_school\labs12-rxid\DS\data\train\round\68462-0249-20_8E0EC736.jpg
# C:\Users\Gutierrez\Documents\DataScience\lambda_school\labs12-rxid\DS\data\train\round\68462-0330-90_NLMIMAGE10_F4497A6B.jpg
# C:\Users\Gutierrez\Documents\DataScience\lambda_school\labs12-rxid\DS\data\train\round\684620147.jpg
# C:\Users\Gutierrez\Documents\DataScience\lambda_school\labs12-rxid\DS\data\train\round\684620165.jpg
# C:\Users\Gutierrez\Documents\DataScience\lambda_school\labs12-rxid\DS\data\train\round\684620555.jpg
# C:\Users\Gutierrez\Documents\DataScience\lambda_school\labs12-rxid\DS\data\train\round\68774-0400-01_NLMIMAGE10_D803EC2F.jpg
# C:\Users\Gutierrez\Documents\DataScience\lambda_school\labs12-rxid\DS\data\train\round\688500005.jpg
# C:\Users\Gutierrez\Documents\DataScience\lambda_school\labs12-rxid\DS\data\train\round\688500012.jpg
# C:\Users\Gutierrez\Documents\DataScience\lambda_school\labs12-rxid\DS\data\train\round\69097-0122-12_NLMIMAGE10_AD4356FA.jpg
# C:\Users\Gutierrez\Documents\DataScience\lambda_school\labs12-rxid\DS\data\train\round\762820206.jpg
# C:\Users\Gutierrez\Documents\DataScience\lambda_school\labs12-rxid\DS\data\train\round\762820207.jpg
# C:\Users\Gutierrez\Documents\DataScience\lambda_school\labs12-rxid\DS\data\train\round\762820249.jpg
# C:\Users\Gutierrez\Documents\DataScience\lambda_school\labs12-rxid\DS\data\train\round\762820250.jpg
# C:\Users\Gutierrez\Documents\DataScience\lambda_school\labs12-rxid\DS\data\train\round\762820251.jpg
# C:\Users\Gutierrez\Documents\DataScience\lambda_school\labs12-rxid\DS\data\train\round\762820256.jpg
# C:\Users\Gutierrez\Documents\DataScience\lambda_school\labs12-rxid\DS\data\train\round\762820302.jpg
# C:\Users\Gutierrez\Documents\DataScience\lambda_school\labs12-rxid\DS\data\train\round\762820334.jpg
# C:\Users\Gutierrez\Documents\DataScience\lambda_school\labs12-rxid\DS\data\train\round\762820417.jpg
# C:\Users\Gutierrez\Documents\DataScience\lambda_school\labs12-rxid\DS\data\train\round\762820418.jpg
# C:\Users\Gutierrez\Documents\DataScience\lambda_school\labs12-rxid\DS\data\train\round\762820422.jpg
# C:\Users\Gutierrez\Documents\DataScience\lambda_school\labs12-rxid\DS\data\train\round\76439-0141-11_NLMIMAGE10_8440C236.jpg
# C:\Users\Gutierrez\Documents\DataScience\lambda_school\labs12-rxid\DS\data\train\round\764390217.jpg
# C:\Users\Gutierrez\Documents\DataScience\lambda_school\labs12-rxid\DS\data\train\round\764390309.jpg

# %%
# image_splitter('round', 'test')

# %% [markdown]
# # Splitting images in half horizontally

# %%
def image_hsplitter(shape, train_or_test):
    '''
    Function to split images in train or test folder according based on shape.
    Function takes two strings, one for shape (i.e., round, capsule, oval) and another for either "train" or "test".
    '''
    
    import os
    import imageio
    
    # partial path for creating new directory and saving files
    partial_path = "C:\\Users\\Gutierrez\\Documents\\DataScience\\lambda_school\\labs12-rxid\\DS\\data\\"
    
    # making new folder for image halves
    new_folder = partial_path + train_or_test + "\\" + shape + "_h\\"

    os.makedirs(new_folder)
    
    # path to loop through
    folder_path = partial_path + train_or_test + "\\" + shape
    # print(folder_path)
    
    # image counter for image halves maded and saved
    img_ctr = 0
    
    # looping through all images in folder and processing
    for file in os.listdir(folder_path):
        file_name = os.path.join(folder_path, file)
        # print(file_name)
        img = imageio.imread(file_name)
        height, width = img.shape[:2]

        # Cut the image in half horizontally
        height_cutoff = height // 2
        s1 = img[:height_cutoff, :]
        s2 = img[height_cutoff:, :]
        
        # Save each half
        filepath_h1 = new_folder + "h1_" + file
        filepath_h2 = new_folder + "h2_" + file
        
        imageio.imwrite(filepath_h1, s1)
        imageio.imwrite(filepath_h2, s2)
        img_ctr +=2
        
    print('Total images (halves) saved:', img_ctr)

# %% [markdown]
# #### CAPSULE "Train" Folder

# %%
image_hsplitter('capsule', 'train')
# Out:
# Total images (halves) saved: 1536

# %% [markdown]
# #### CAPSULE "Test" Folder

# %%
image_hsplitter('capsule', 'test')
# Out:
# Total images (halves) saved: 612

# %% [markdown]
# # Renaming files for Neural Network

# %%
# Need images labeled like "cat.1" or "dog.3" and so on

# You could then use it in your example like this:
# rename(r'c:\temp\xx', r'*.doc', r'new(%s)')
# The above example will convert all *.doc files in c:\temp\xx dir to new(%s).doc, 
# where %s is the previous base name of the file (without extension).

import glob, os

def rename_files(dir, pattern, titlePattern):
    ctr = 1
    for pathAndFilename in glob.iglob(os.path.join(dir, pattern)):
        title, ext = os.path.splitext(os.path.basename(pathAndFilename))
        os.rename(pathAndFilename, 
                  os.path.join(dir, titlePattern % ctr + ext))
        ctr += 1

# %% [markdown]
# #### Train images

# %%
# rename_files(r"C:\\Users\\Gutierrez\\Documents\\DataScience\\lambda_school\\labs12-rxid\\DS\\data\\train\\round_h",
#             r"*.jpg",
#             r"rnd.%s")

# %%
# rename_files(r"C:\\Users\\Gutierrez\\Documents\\DataScience\\lambda_school\\labs12-rxid\\DS\\data\\train\\capsule_h",
#             r"*.jpg",
#             r"cap.%s")

# %% [markdown]
# #### Test images

# %%
# rename_files(r"C:\\Users\\Gutierrez\\Documents\\DataScience\\lambda_school\\labs12-rxid\\DS\\data\\test\\round_h",
#             r"*.jpg",
#             r"rnd.%s")

# %%
# rename_files(r"C:\\Users\\Gutierrez\\Documents\\DataScience\\lambda_school\\labs12-rxid\\DS\\data\\test\\capsule_h",
#             r"*.jpg",
#             r"cap.%s")

# %% [markdown]
# # CHECKING FOR `COLOR` & `SHAPE`

# %%
df[df['splcolor_text'] == 'C48329']
# Out:
#           ID  Enabled?                                               spp  \
# 46503  48054      True  6ae13cb4-0316-40d1-9216-c7d5556aaed3-10631-490-0
#
#                                       setid  splsize  pillbox_size splshape  \
# 46503  6ae13cb4-0316-40d1-9216-c7d5556aaed3     18.0           NaN   C48345
#
#       splshape_text pillbox_shape_text  splscore  pillbox_score splimprint  \
# 46503          OVAL                NaN       1.0            NaN         pp
#
#       pillbox_imprint splcolor splcolor_text pillbox_color_text spl_strength  \
# 46503              ST      NaN        C48329              GREEN          NaN
#
#       spl_ingredients spl_inactive_ing source rxtty  \
# 46503             NaN                           HRX
#
#                                                    rxcui product_code  \
# 46503  Verapamil hydrochloride 240 MG Extended Releas...       897714
#
#         part_num part_medicine_name ndc_labeler_code ndc_product_code  \
# 46503  10631-490                  0        106310490            10631
#
#       medicine_name marketing_act_code effective_time file_name  \
# 46503           490         Isoptin SR            NaN  20080311
#
#                              equal_product_code dosage_form document_type  \
# 46503  6ae13cb4-0316-40d1-9216-c7d5556aaed3.xml         NaN        C42897
#
#       dea_schedule_code dea_schedule_name author_type  \
# 46503           34391-3               NaN         NaN
#
#                    approval_code image_source splimage epc_match  \
# 46503  Ranbaxy Laboratories Inc.          NaN      NaN     FALSE
#
#       version_number laberer_code application_number  spl_id       NDC9  \
# 46503            NaN            1                NaN     NaN  106310490
#
#       PRODUCT_CODE EQUAL_PRODUCT_CODE                     author  \
# 46503    10631-490                NaN  Ranbaxy Laboratories Inc.
#
#       DEA_SCHEDULE_CODE                                           RXSTRING  \
# 46503               NaN  Verapamil hydrochloride 240 MG Extended Releas...
#
#       image_id  HAS_IMAGE  FROM_SIS  NO_RXCUI
# 46503      NaN          0       NaN       NaN

# %%
df[df['product_code'] == '897714']
# Out:
#           ID  Enabled?                                               spp  \
# 46503  48054      True  6ae13cb4-0316-40d1-9216-c7d5556aaed3-10631-490-0
#
#                                       setid  splsize  pillbox_size splshape  \
# 46503  6ae13cb4-0316-40d1-9216-c7d5556aaed3     18.0           NaN   C48345
#
#       splshape_text pillbox_shape_text  splscore  pillbox_score splimprint  \
# 46503          OVAL                NaN       1.0            NaN         pp
#
#       pillbox_imprint splcolor splcolor_text pillbox_color_text spl_strength  \
# 46503              ST      NaN        C48329              GREEN          NaN
#
#       spl_ingredients spl_inactive_ing source rxtty  \
# 46503             NaN                           HRX
#
#                                                    rxcui product_code  \
# 46503  Verapamil hydrochloride 240 MG Extended Releas...       897714
#
#         part_num part_medicine_name ndc_labeler_code ndc_product_code  \
# 46503  10631-490                  0        106310490            10631
#
#       medicine_name marketing_act_code effective_time file_name  \
# 46503           490         Isoptin SR            NaN  20080311
#
#                              equal_product_code dosage_form document_type  \
# 46503  6ae13cb4-0316-40d1-9216-c7d5556aaed3.xml         NaN        C42897
#
#       dea_schedule_code dea_schedule_name author_type  \
# 46503           34391-3               NaN         NaN
#
#                    approval_code image_source splimage epc_match  \
# 46503  Ranbaxy Laboratories Inc.          NaN      NaN     FALSE
#
#       version_number laberer_code application_number  spl_id       NDC9  \
# 46503            NaN            1                NaN     NaN  106310490
#
#       PRODUCT_CODE EQUAL_PRODUCT_CODE                     author  \
# 46503    10631-490                NaN  Ranbaxy Laboratories Inc.
#
#       DEA_SCHEDULE_CODE                                           RXSTRING  \
# 46503               NaN  Verapamil hydrochloride 240 MG Extended Releas...
#
#       image_id  HAS_IMAGE  FROM_SIS  NO_RXCUI
# 46503      NaN          0       NaN       NaN

# %%
df[['spl_ingredients','splimprint', 'splcolor_text', 'splcolor', 'splshape_text', 'splshape', 'rxcui']][df['rxcui'].str.contains('Verapamil', na=False)]
# Out:
#                            spl_ingredients                   splimprint  \
# 1279   VERAPAMIL HYDROCHLORIDE[VERAPAMIL];                        M;411
# 2404   VERAPAMIL HYDROCHLORIDE[VERAPAMIL];                          292
# 2469   VERAPAMIL HYDROCHLORIDE[VERAPAMIL];                          G74
# 3654   VERAPAMIL HYDROCHLORIDE[VERAPAMIL];                         7300
# 4653   VERAPAMIL HYDROCHLORIDE[VERAPAMIL];                          117
# 5643   verapamil hydrochloride[verapamil];  SCHWARZ;2489;VERELAN;180;mg
# 5710   VERAPAMIL HYDROCHLORIDE[VERAPAMIL];                        HP;27
# 6482   VERAPAMIL HYDROCHLORIDE[VERAPAMIL];                        HP;59
# 6651   VERAPAMIL HYDROCHLORIDE[VERAPAMIL];                         P;SC
# 6732   VERAPAMIL HYDROCHLORIDE[VERAPAMIL];                        HP;59
# 6797   VERAPAMIL HYDROCHLORIDE[VERAPAMIL];                          116
# 7733   VERAPAMIL HYDROCHLORIDE[VERAPAMIL];                          118
# 7777   VERAPAMIL HYDROCHLORIDE[VERAPAMIL];                          G74
# 7883   VERAPAMIL HYDROCHLORIDE[VERAPAMIL];                    MYLAN;244
# 9043   VERAPAMIL HYDROCHLORIDE[VERAPAMIL];                          118
# 9450   VERAPAMIL HYDROCHLORIDE[VERAPAMIL];                293;Breakline
# 9472   VERAPAMIL HYDROCHLORIDE[VERAPAMIL];                         7301
# 9795   VERAPAMIL HYDROCHLORIDE[VERAPAMIL];                 60274;180;mg
# 11638  VERAPAMIL HYDROCHLORIDE[VERAPAMIL];                         7301
# 11978  VERAPAMIL HYDROCHLORIDE[VERAPAMIL];                   MYLAN;6320
# 13607  VERAPAMIL HYDROCHLORIDE[VERAPAMIL];                          292
# 15046  VERAPAMIL HYDROCHLORIDE[VERAPAMIL];                          117
# 15868  VERAPAMIL HYDROCHLORIDE[VERAPAMIL];                    MYLAN;244
# 16039  VERAPAMIL HYDROCHLORIDE[VERAPAMIL];                          120
# 16721  VERAPAMIL HYDROCHLORIDE[VERAPAMIL];                         7300
# 16785  VERAPAMIL HYDROCHLORIDE[VERAPAMIL];                          293
# 16804  VERAPAMIL HYDROCHLORIDE[VERAPAMIL];                          G74
# 17494  verapamil hydrochloride[verapamil];  SCHWARZ;2491;VERELAN;240;mg
# 18178  VERAPAMIL HYDROCHLORIDE[VERAPAMIL];                        M;411
# 18220  VERAPAMIL HYDROCHLORIDE[VERAPAMIL];                          120
# ...                                    ...                          ...
# 42921  VERAPAMIL HYDROCHLORIDE[VERAPAMIL];                        PP;ST
# 43620  VERAPAMIL HYDROCHLORIDE[VERAPAMIL];                          G74
# 43935  VERAPAMIL HYDROCHLORIDE[VERAPAMIL];                          G74
# 44091  VERAPAMIL HYDROCHLORIDE[VERAPAMIL];  SCHWARZ;2495;VERELAN;360;mg
# 45227  VERAPAMIL HYDROCHLORIDE[VERAPAMIL];                        M;312
# 45432  VERAPAMIL HYDROCHLORIDE[VERAPAMIL];                          118
# 46503                                  NaN                           pp
# 49671  VERAPAMIL HYDROCHLORIDE[VERAPAMIL];                          293
# 49925  VERAPAMIL HYDROCHLORIDE[VERAPAMIL];                          C77
# 50319  VERAPAMIL HYDROCHLORIDE[VERAPAMIL];                          293
# 51338  VERAPAMIL HYDROCHLORIDE[VERAPAMIL];  SCHWARZ;2491;VERELAN;240;mg
# 51539  VERAPAMIL HYDROCHLORIDE[VERAPAMIL];                    MYLAN;244
# 52161  VERAPAMIL HYDROCHLORIDE[VERAPAMIL];                 60274;360;mg
# 52686  VERAPAMIL HYDROCHLORIDE[VERAPAMIL];                          292
# 56248  VERAPAMIL HYDROCHLORIDE[VERAPAMIL];                        M;411
# 56379  VERAPAMIL HYDROCHLORIDE[VERAPAMIL];                   MYLAN;6380
# 56608                                  NaN                           pp
# 56760  VERAPAMIL HYDROCHLORIDE[VERAPAMIL];                        HP;27
# 58754  VERAPAMIL HYDROCHLORIDE[VERAPAMIL];                          G74
# 59097                                  NaN                            p
# 59329  verapamil hydrochloride[verapamil];  SCHWARZ;2490;VERELAN;120;mg
# 59750  VERAPAMIL HYDROCHLORIDE[VERAPAMIL];                          118
# 59973  VERAPAMIL HYDROCHLORIDE[VERAPAMIL];                          G74
# 60171  VERAPAMIL HYDROCHLORIDE[VERAPAMIL];                          G74
# 60561  VERAPAMIL HYDROCHLORIDE[VERAPAMIL];                        M;411
# 61142  VERAPAMIL HYDROCHLORIDE[VERAPAMIL];                         7300
# 61599  VERAPAMIL HYDROCHLORIDE[VERAPAMIL];                         7300
# 61756  verapamil hydrochloride[verapamil];          SCHWARZ;4087;300;mg
# 62734  VERAPAMIL HYDROCHLORIDE[VERAPAMIL];                
# 59973  Verapamil hydrochloride 240 MG Extended Releas...
# 60171  Verapamil hydrochloride 240 MG Extended Releas...
# 60561  Verapamil hydrochloride 240 MG Extended Releas...
# 61142  Verapamil hydrochloride 240 MG Extended Releas...
# 61599  Verapamil hydrochloride 240 MG Extended Releas...
# 61756  24 HR Verapamil hydrochloride 300 MG Extended ...
# 62734         Verapamil hydrochloride 120 MG Oral Tablet
# 62879  Verapamil hydrochloride 180 MG Extended Releas...
#
# [98 rows x 7 columns]

# %%
df[['splcolor_text', 'splcolor']][df['splcolor']=='C48329']
# Out:
#       splcolor_text splcolor
# 0             GREEN   C48329
# 2             GREEN   C48329
# 8             GREEN   C48329
# 9             GREEN   C48329
# 16            GREEN   C48329
# 54            GREEN   C48329
# 70            GREEN   C48329
# 73            GREEN   C48329
# 74            GREEN   C48329
# 87            GREEN   C48329
# 88            GREEN   C48329
# 95            GREEN   C48329
# 97            GREEN   C48329
# 139           GREEN   C48329
# 158           GREEN   C48329
# 177           GREEN   C48329
# 181           GREEN   C48329
# 201           GREEN   C48329
# 208           GREEN   C48329
# 212           GREEN   C48329
# 262           GREEN   C48329
# 314           GREEN   C48329
# 331           GREEN   C48329
# 332           GREEN   C48329
# 392           GREEN   C48329
# 403           GREEN   C48329
# 431           GREEN   C48329
# 441           GREEN   C48329
# 465           GREEN   C48329
# 548           GREEN   C48329
# ...             ...      ...
# 62382         GREEN   C48329
# 62397         GREEN   C48329
# 62399         GREEN   C48329
# 62400         GREEN   C48329
# 62448         GREEN   C48329
# 62525         GREEN   C48329
# 62534         GREEN   C48329
# 62551         GREEN   C48329
# 62556         GREEN   C48329
# 62576         GREEN   C48329
# 62582         GREEN   C48329
# 62589         GREEN   C48329
# 62603         GREEN   C48329
# 62604         GREEN   C48329
# 62605         GREEN   C48329
# 62622         GREEN   C48329
# 62627         GREEN   C48329
# 62638         GREEN   C48329
# 62650         GREEN   C48329
# 62677         GREEN   C48329
# 62692         GREEN   C48329
# 62703         GREEN   C48329
# 62739         GREEN   C48329
# 62751         GREEN   C48329
# 62763         GREEN   C48329
# 62786         GREEN   C48329
# 62794         GREEN   C48329
# 62814         GREEN   C48329
# 62828         GREEN   C48329
# 62889         GREEN   C48329
#
# [2980 rows x 2 columns]

# %%
df[df[('HAS_IMAGE' == 1)]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-48c02d68fd1c> in <module>()
# ----> 1 df[df[('HAS_IMAGE' == 1)]]
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False

# %%
df[(df['HAS_IMAGE'] == 1)].splshape_text.value_counts()
# Out:
# ROUND                 4132
# OVAL                  2320
# CAPSULE               1958
# RECTANGLE               56
# TRIANGLE                49
# DIAMOND                 37
# FREEFORM                21
# SQUARE                  20
# TRAPEZOID               19
# HEXAGON (6 SIDED)       17
# OCTAGON (8 SIDED)       12
# PENTAGON (5 SIDED)      11
# TEAR                     6
# BULLET                   4
# DOUBLE CIRCLE            4
# SEMI-CIRCLE              1
# Name: splshape_text, dtype: int64

# %%
df[(df['HAS_IMAGE'] == 1)].splshape_text.value_counts().sum()
# Out:
# 8667
