# %%
import cv2
import imageio

# %%
def wsplit(fp):
    img = cv2.imread(path + fn)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    height, width = img.shape
    width_cutoff = width // 2
    s1 = img[:, :width_cutoff]
    s2 = img[:, width_cutoff:]
    return [img,s1,s2]

# %%
def hsplit(fp):
    img = cv2.imread(path + fn)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    height, width = img.shape
    width_cutoff = width // 2
    height_cutoff = height // 2
    s1 = img[:height_cutoff,:]
    s2 = img[height_cutoff:,:]
    return [img,s1,s2]

# %%
from matplotlib import pyplot as plt

# %%
path = "/home/mark/lambda/pill_identifier/pill-identifier-trainer/anpr_ocr/data/anpr_ocr__train/img/"
fn = '00007-4139-20_9C18CE46.jpg'
for img in hsplit(path+fn):
    plt.imshow(img)
    plt.show()

# %%
fn = '00002-4770-90_9516CAA6.jpg'
for img in wsplit(path+fn):
    plt.imshow(img)
    plt.show()
